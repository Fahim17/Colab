# %%
# !wget  -q -O input.jpg
path = 'https://scontent.fdac23-1.fna.fbcdn.net/v/t1.0-9/53566454_2254325127961985_8173496113463033856_n.jpg?_nc_cat=111&_nc_sid=cdbe9c&_nc_ohc=qZsCMZoORtMAX_y2Arb&_nc_ht=scontent.fdac23-1.fna&oh=bcdabd7fe3cf4facdc8395170dd7ab92&oe=5F6E1F73'

# %%
import requests
from os.path  import basename
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.facebook.com/boibd24/photos/?tab=album&album_id=2254324734628691"
# page = urlopen(url)
page = requests.get(url).text
soup = BeautifulSoup(page, features="lxml")

getAll = soup.find_all("img")

print(getAll)

# with open(basename("4.jpg"), "wb") as f:
#             f.write(requests.get(path).content)
# Out:
# [<img alt="" class="scaledImageFitWidth img" data-ft='{"tn":"-^"}' data-src="https://scontent-ort2-2.xx.fbcdn.net/v/t1.0-1/37019456_1881298858597949_3944381257500065792_n.jpg?_nc_cat=109&amp;_nc_sid=dbb9e7&amp;_nc_ohc=-pBEbSWjThAAX_hXDDS&amp;_nc_ht=scontent-ort2-2.xx&amp;oh=d4ea7f7da4915289f7880a3dd228b659&amp;oe=5F6DCDE1" height="500" itemprop="image" src="https://scontent-ort2-2.xx.fbcdn.net/v/t1.0-1/37019456_1881298858597949_3944381257500065792_n.jpg?_nc_cat=109&amp;_nc_sid=dbb9e7&amp;_nc_ohc=-pBEbSWjThAAX_hXDDS&amp;_nc_ht=scontent-ort2-2.xx&amp;oh=d4ea7f7da4915289f7880a3dd228b659&amp;oe=5F6DCDE1" width="500"/>, <img height="0" src="https://facebook.com/security/hsts-pixel.gif?c=3.2.5" style="display:none" width="0"/>]

# %%
pip list
